# %%
import pandas as pd
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None)

# %% [markdown]
# CCM Computing Literacy Course Entry Survey - Fall 2021: https://docs.google.com/spreadsheets/d/1NQefsnhUVorK-6iD2qrnpC75JHeSfFZTpR-gCXVVqR4/edit?usp=sharing
# CCM Computing Entry Survey - Fall 2021 (Responses): https://docs.google.com/spreadsheets/d/1xBLuCkDG9NVRhU0jWpXJIkvrdUk_pStAkmCQPY4BLkA/edit?usp=sharing
# CCM Computing Entry Survey - Fall 2020 (Responses): https://docs.google.com/spreadsheets/d/133ndHUX4kzhcMSUFKY0fl3CWgZ9LMEJGAjt286LnFvY/edit?usp=sharing
# CCM Computing Literacy Course Entry Survey - Fall 2020 (Responses): https://docs.google.com/spreadsheets/d/1fBe7xC-HT-UiRXsAmhkkfcL2_VDhY2PCQyucOwVHFyQ/edit?usp=sharing

# %%
datafile = "Survey Datasheet"
df = pd.read_html #read in setup data

# %%
df
# Out:
# <function pandas.io.html.read_html(io: Union[str, pathlib.Path, IO[~AnyStr]], match: Union[str, Pattern] = '.+', flavor: Union[str, NoneType] = None, header: Union[int, Sequence[int], NoneType] = None, index_col: Union[int, Sequence[int], NoneType] = None, skiprows: Union[int, Sequence[int], slice, NoneType] = None, attrs: Union[Dict[str, str], NoneType] = None, parse_dates: bool = False, thousands: Union[str, NoneType] = ',', encoding: Union[str, NoneType] = None, decimal: str = '.', converters: Union[Dict, NoneType] = None, na_values=None, keep_default_na: bool = True, displayed_only: bool = True) -> List[pandas.core.frame.DataFrame]>

# %%
datafile = "CCM Computing Literacy Course Entry Survey - Fall 2021 - Sheet1.csv"
df = pd.read_csv(datafile, index_col=0,parse_dates=True) #Display selected.csv file

# %%
df
# Out:
#                             Which course are you currently enrolled in?  \
# Timestamp
# 2021-10-04 13:43:00-04:00  CMP 126 Computer Technology and Applications
# 2021-10-04 14:15:38-04:00  CMP 126 Computer Technology and Applications
# 2021-10-04 15:06:08-04:00  CMP 126 Computer Technology and Applications
# 2021-10-04 18:32:07-04:00         CMP 101 Computer Information Literacy
# 2021-10-05 19:22:53-04:00  CMP 126 Computer Technology and Applications
# 2021-10-05 19:25:38-04:00  CMP 126 Computer Technology and Applications
# 2021-10-05 19:35:11-04:00  CMP 126 Computer Technology and Applications
# 2021-10-05 20:51:17-04:00  CMP 126 Computer Technology and Applications
# 2021-10-05 21:23:52-04:00  CMP 126 Computer Technology and Applications
# 2021-10-06 06:39:23-04:00  CMP 126 Computer Technology and Applications
# 2021-10-06 08:22:56-04:00  CMP 126 Computer Technology and Applications
# 2021-10-06 10:18:02-04:00         CMP 101 Computer Information Literacy
# ...

# %%
df.shape
# Out:
# (122, 74)

# %%
df.columns
# Out:
# Index(['Which course are you currently enrolled in?',
#        'What motivated you to seek a computing class at CCM? [It’s a required class for the degree I’m seeking]',
#        'What motivated you to seek a computing class at CCM? [To keep current in computing skills]',
#        'What motivated you to seek a computing class at CCM? [Career Advancement]',
#        'What motivated you to seek a computing class at CCM? [Career Change]',
#        'What motivated you to seek a computing class at CCM? [Professional Development]',
#        'What motivated you to seek a computing class at CCM? [Job Displacement]',
#        'What motivated you to seek a computing class at CCM? [Relocation]',
#        'What motivated you to seek a computing class at CCM? [IT Industry Certifications]',
#        'What motivated you to seek a computing class at CCM? [Financial]',
#        'What motivated you to seek a computing class at CCM? [Personal Enrichment]',
# ...

# %%
df[["On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?"]]
#Display selected portion of csv file
# Out:
#                            On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you taking more courses in Computer Science, Information Technology or Game Development?
# Timestamp
# 2021-10-04 13:43:00-04:00                                                  3
# 2021-10-04 14:15:38-04:00                                                  1
# 2021-10-04 15:06:08-04:00                                                  3
# 2021-10-04 18:32:07-04:00                                                  1
# 2021-10-05 19:22:53-04:00                                                  3
# 2021-10-05 19:25:38-04:00                                                  1
# 2021-10-05 19:35:11-04:00                                                  1
# 2021-10-05 20:51:17-04:00                                                  3
# 2021-10-05 21:23:52-04:00                                                  3
# ...

# %%
datafile = "CCM Computing Literacy Course Entry Survey - Fall 2020 (Responses) - Form Responses 1.csv"
df = pd.read_csv(datafile, index_col=0,parse_dates=True) #Display selected.csv file

# %%
df
# Out:
#                       Which course are you currently enrolled in?  \
# Timestamp
# 2020-07-08 11:30:23   CMP 135 Computer Concepts with Applications
# 2020-07-08 12:15:09   CMP 135 Computer Concepts with Applications
# 2020-07-08 12:22:23   CMP 135 Computer Concepts with Applications
# 2020-07-08 15:14:53   CMP 135 Computer Concepts with Applications
# 2020-07-08 16:34:12   CMP 135 Computer Concepts with Applications
# ...                                                           ...
# 2020-09-27 18:07:36   CMP 135 Computer Concepts with Applications
# 2020-09-30 09:45:44   CMP 135 Computer Concepts with Applications
# 2020-09-30 18:35:40         CMP 101 Computer Information Literacy
# 2020-10-04 19:44:31  CMP 126 Computer Technology and Applications
# 2020-10-10 16:59:30  CMP 126 Computer Technology and Applications
#
#                     What motivated you to seek a computing class at CCM?  \
# Timestamp
# 2020-07-08 11:30:23   It’s a required class for the degree I’m seeking
# ...

# %%
df.shape
# Out:
# (245, 93)

# %%
df.columns
# Out:
# Index(['Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
#        'How did you hear about County College of Morris? [Television]',
# ...

# %%
datafile = "CCM Computing Entry Survey - Fall 2021 (Responses) - Form Responses 1.csv"
df = pd.read_csv(datafile, index_col=0,parse_dates=True) #Display selected.csv file

# %%
df
# Out:
#                                 Which course are you enrolled in?  \
# Timestamp
# 2021-10-03 22:49:52                    CMP 128 Computer Science I
# 2021-10-04 07:31:10                    CMP 128 Computer Science I
# 2021-10-04 08:57:05                    CMP 128 Computer Science I
# 2021-10-04 10:20:16                    CMP 128 Computer Science I
# 2021-10-04 12:26:08                    CMP 128 Computer Science I
# ...                                                           ...
# 2021-10-22 18:07:52                           CMP 130 Intro to IT
# 2021-10-22 20:34:04  CMP 131 Fundamentals of Programming (Python)
# 2021-10-22 20:36:54  CMP 131 Fundamentals of Programming (Python)
# 2021-12-17 10:13:34                           CMP 130 Intro to IT
# 2021-12-17 13:11:41                    CMP 128 Computer Science I
#
#                     How did you hear about County College of Morris? [CCM Web site]  \
# Timestamp
# ...

# %%
df.shape
# Out:
# (245, 93)

# %%
df.columns
# Out:
# Index(['Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
#        'How did you hear about County College of Morris? [Television]',
# ...

# %%
datafile = "CCM Computing Entry Survey - Fall 2020 (Responses) - Form Responses 1.csv"
df = pd.read_csv(datafile, index_col=0,parse_dates=True) #Display selected.csv file

# %%
df
# Out:
#                                 Which course are you enrolled in?  \
# Timestamp
# 2020-07-28 16:21:37            CMP 239 Internet & Web Page Design
# 2020-07-28 17:07:22            CMP 239 Internet & Web Page Design
# 2020-07-28 21:12:47            CMP 239 Internet & Web Page Design
# 2020-07-29 11:53:04            CMP 239 Internet & Web Page Design
# 2020-07-29 17:26:22            CMP 239 Internet & Web Page Design
# ...                                                           ...
# 2020-10-13 18:07:17                           CMP 130 Intro to IT
# 2020-10-14 11:08:02  CMP 131 Fundamentals of Programming (Python)
# 2020-10-14 19:18:26  CMP 131 Fundamentals of Programming (Python)
# 2020-10-22 19:59:06                    CMP 128 Computer Science I
# 2020-10-26 14:27:44                    CMP 128 Computer Science I
#
#                     How did you hear about County College of Morris? [CCM Web site]  \
# Timestamp
# ...

# %%
df.shape
# Out:
# (298, 82)

# %%
df.columns
# Out:
# Index(['Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
#        'How did you hear about County College of Morris? [Television]',
# ...

# %%
import pandas as pd

data1 = pd.read_csv('CCM Computing Literacy Course Entry Survey - Fall 2021 - Sheet1.csv')
data2 = pd.read_csv('CCM Computing Literacy Course Entry Survey - Fall 2020 (Responses) - Form Responses 1.csv')
  
# using merge function by setting how='outer'
output4 = pd.merge(data1, data2, 
                   on='Timestamp', 
                   how='inner')
  
# displaying result
print(output4)
# Out:
# Empty DataFrame
# ...
